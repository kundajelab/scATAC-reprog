# %%
import scvelo as scv
import scanpy as sc
from matplotlib import rcParams
scv.logging.print_version()
# Out:
# SURAG CHANGED utils.py
# Running scvelo 0.2.2 (python 3.8.2) on 2020-10-11 05:53.

# %%
adata = scv.datasets.dentategyrus()
adata
# Out:
# AnnData object with n_obs × n_vars = 2930 × 13913
#     obs: 'clusters', 'age(days)', 'clusters_enlarged'
#     uns: 'clusters_colors'
#     obsm: 'X_umap'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
scv.pl.proportions(adata)

# %%
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Exctracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
rcParams['figure.figsize'] = 4, 4
import pandas as pd
pd.DataFrame(adata.layers['velocity']>=0).mean(0).hist(bins=25)

# %%
scv.tl.velocity(adata, mode='stochastic')
# Out:
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)

# %%
scv.tl.velocity_graph(adata)
# Out:
# SURAG UNCOMMENTED velocity_graph.py
# computing velocity graph
#     finished (0:00:04) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
rcParams['figure.figsize'] = 8, 8

scv.pl.velocity_embedding_stream(adata, basis='umap')
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.tl.rank_velocity_genes(adata, groupby='clusters', min_corr=.3)

df = scv.DataFrame(adata.uns['rank_velocity_genes']['names'])
df.head()
# Out:
# ranking velocity genes
#     finished (0:00:01) --> added
#     'rank_velocity_genes', sorted scores by group ids (adata.uns)
#     'spearmans_score', spearmans correlation scores (adata.var)
#   Astrocytes Cajal Retzius  Cck-Tox Endothelial    GABA Granule immature  \
# 0      Phkg1        Dpysl3  Golga7b    Serpine2   Vsnl1           Shisa9
# 1     Ctnnd2        Tmem47    Rab3c       Ptprg  Lancl1             Jph1
# 2      Lsamp       Sh3glb1     Irf9       Prex2   Mtus2           Sphkap
# 3         Qk          Scg3    Cplx2    Arhgap31   Stmn2            Pgbd5
# 4      Cspg5         Pacrg    Ptprd      Arrdc2  Elavl3           Gabrb3
#
#   Granule mature Microglia   Mossy Neuroblast      OL       OPC  \
# 0          Sgsm2    Srgap2    Chgb        Mt3  Gprc5b    Hmgcs1
# 1          Ntng1     Clic4  Pgm2l1      Gdpd1    Clmn     Luzp2
# 2          Grasp      Ssh2   Fxyd1    Slc38a2   Pcdh9  Ppp1r14c
# 3  2010300C02Rik        Qk   Mapk6       Bzw2    Gatm    Elavl3
# 4          Wasf1       Hn1  Osbpl6      Epha4  Tmeff2     Lsamp
#
#   Radial Glia-like     nIPC
# 0    2810459M11Rik  Smarcc1
# 1          Hepacam  Igfbpl1
# 2           Ctnnd2     Bzw2
# 3          Sparcl1    Tbrg4
# 4            Lsamp   Rps27l

# %%
rcParams['figure.figsize'] = 12, 10

scv.pl.velocity(adata, 
                ['Ntng1'], 
                size=20, 
                fontsize=20,
                dpi=300,
                ncols=1)

# %%
scv.tl.velocity_graph(adata, 
                      gene_subset=df['Granule immature'][:1]
#                       gene_subset=list(adata.uns['rank_genes_groups']['names']['Delta'])[:5]
                     )
# Out:
# SURAG UNCOMMENTED velocity_graph.py
# computing velocity graph
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-e08ad6cd7192> in <module>
# ----> 1 scv.tl.velocity_graph(adata,
#       2                       gene_subset=df['Granule immature'][:1]
#       3 #                       gene_subset=list(adata.uns['rank_genes_groups']['names']['Delta'])[:5]
#       4                      )
#
# ~/anaconda3/envs/r36_cran/lib/python3.8/site-packages/scvelo/tools/velocity_graph.py in velocity_graph(data, vkey, xkey, tkey, basis, n_neighbors, n_recurse_neighbors, random_neighbors_at_max, sqrt_transform, variance_stabilization, gene_subset, compute_uncertainties, approx, mode_neighbors, copy)
#     318
#     319     logg.info("computing velocity graph", r=True)
# --> 320     vgraph.compute_cosines()
#     321
#     322     adata.uns[f"{vkey}_graph"] = vgraph.graph
#
# ~/anaconda3/envs/r36_cran/lib/python3.8/site-packages/scvelo/tools/velocity_graph.py in compute_cosines(self)
#     199             progress.finish()
#     200
# --> 201         vals = np.hstack(vals)
#     202         vals[np.isnan(vals)] = 0
#     203
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# ~/anaconda3/envs/r36_cran/lib/python3.8/site-packages/numpy/core/shape_base.py in hstack(tup)
#     343         return _nx.concatenate(arrs, 0)
#     344     else:
# --> 345         return _nx.concatenate(arrs, 1)
#     346
#     347
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
rcParams['figure.figsize'] = 8, 8

scv.pl.velocity_embedding_stream(adata, basis='umap', legend_fontsize=0)
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
rcParams['figure.figsize'] = 4, 4
import pandas as pd
pd.DataFrame(adata.layers['velocity']>=0).mean(0).hist(bins=25)
