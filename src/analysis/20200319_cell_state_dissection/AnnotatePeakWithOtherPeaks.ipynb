# %% [markdown]
# # Annotate Peaks with Other Peaks
#
# Perform intersections of peak sets with other peaks sets.
#
# **TODO**: Organize reference beds used and keep a copy of them in `resources`.

# %%
BASE=~/kundajelab/scATAC-reprog/
ANALYSIS=$BASE/src/analysis/20200319_cell_state_dissection
BEDS=$ANALYSIS/beds/20200328_tmp_n20
NUM_BEDS=20
RES=$BASE/resources/

# %%
# function definition that performs intersection of each cluster peak set 
# with reference peak set

# expects reference peaks to be in ./tmp.bed
# arguments are REF_BED, NUM_BEDS, BEDS directory (which should have idx1.bed,...idx{NUM_BEDS}.bed)
intersection_stats () {
    TOT=$(cat $1 | wc -l)
    printf "TOTAL PEAKS : $TOT\n\n"

    (printf "Cluster Intersect Total Percent\n" ;
    for i in $(seq 1 $2)
     do INT=$(bedtools intersect -b <(cat $1 |  cut -f1-3) \
       -a $3/idx${i}.1000bp.bed -c \
       | awk '$4>0{s+=1} END{print s}') ; 
       TOT=$(cat  $3/idx${i}.1000bp.bed | wc -l ) ; 
       FRAC=$(echo "100*$INT/$TOT" | bc -l | awk '{printf "%.4f\n", $0}') ; 
       printf "$i $INT $TOT $FRAC\n" 
    done)  | column -t
}

# %%
REF=../20200307_fine_clustering/beds/20200307_gridmap_naive_n15/idx3.1000bp.bed
intersection_stats $REF $NUM_BEDS $BEDS
# Out:
# TOTAL PEAKS : 35705
#
# Cluster  Intersect  Total  Percent
# 1        516        34092  1.5136
# 2        449        19069  2.3546
# 3        142        23336  0.6085
# 4        4961       29829  16.6315
# 5        414        25973  1.5940
# 6        719        12165  5.9104
# 7        9          12659  0.0711
# 8        519        9759   5.3182
# 9        6497       27171  23.9115
# 10       7991       24117  33.1343
# 11       1542       22395  6.8855
# 12       1127       31960  3.5263
# 13       2497       14540  17.1733
# 14       7258       23151  31.3507
# 15       7558       27353  27.6313
# 16       5201       36492  14.2524
# 17       1300       18391  7.0687
# 18       229        24005  0.9540
# 19       424        12382  3.4243
# 20       512        28638  1.7878

# %%
REF=../20200331_gc_stratify/beds/20200403_D0_lt_0.2_quantile_gc10/all_peaks.bed 
intersection_stats $REF $NUM_BEDS $BEDS
# Out:
# TOTAL PEAKS : 91857
#
# (standard_in) 1: syntax error
# Cluster  Intersect  Total  Percent
# 1        38         34092  0.1115
# 2        164        19069  0.8600
# 3        22         23336  0.0943
# 4        7328       29829  24.5667
# 5        69         25973  0.2657
# 6        4142       12165  34.0485
# 7        12659
# 8        3405       9759   34.8909
# 9        8027       27171  29.5425
# 10       7782       24117  32.2677
# 11       840        22395  3.7508
# 12       391        31960  1.2234
# 13       5626       14540  38.6933
# 14       9409       23151  40.6419
# 15       5299       27353  19.3726
# 16       2469       36492  6.7659
# 17       228        18391  1.2397
# 18       8          24005  0.0333
# 19       5676       12382  45.8407
# 20       129        28638  0.4505

# %%
# Intersect peaks in each cluster with H1-hESC ChIP peaks from GSE17917 (Lister et al 2009)
cat $RES/GSE17917/KLF4.hg38.bed $RES/GSE17917/SOX2.hg38.bed $RES/GSE17917/OCT4.hg38.bed > tmp.bed

intersection_stats tmp.bed $NUM_BEDS $BEDS

rm tmp.bed
# Out:
# TOTAL PEAKS : 13360
#
# Cluster  Intersect  Total  Percent
# 1        549        34092  1.6103
# 2        128        19069  0.6712
# 3        1864       23336  7.9877
# 4        638        29829  2.1389
# 5        170        25973  0.6545
# 6        511        12165  4.2006
# 7        1924       12659  15.1987
# 8        220        9759   2.2543
# 9        639        27171  2.3518
# 10       536        24117  2.2225
# 11       623        22395  2.7819
# 12       778        31960  2.4343
# 13       384        14540  2.6410
# 14       289        23151  1.2483
# 15       261        27353  0.9542
# 16       722        36492  1.9785
# 17       254        18391  1.3811
# 18       1017       24005  4.2366
# 19       377        12382  3.0447
# 20       1308       28638  4.5674

# %%
# Intersect peaks in each cluster with H1-hESC ATAC peaks
REF=~/kundajelab/heterokaryon-v2/src/analysis/20191002_surag_heterokaryon_clustering/data/H1.hESC.atac.idr.peaks.liftover.to.hg38.bed

intersection_stats $REF $NUM_BEDS $BEDS
# Out:
# TOTAL PEAKS : 149765
#
# Cluster  Intersect  Total  Percent
# 1        4570       34092  13.4049
# 2        1108       19069  5.8105
# 3        13043      23336  55.8922
# 4        3972       29829  13.3159
# 5        1523       25973  5.8638
# 6        1589       12165  13.0621
# 7        11225      12659  88.6721
# 8        1337       9759   13.7002
# 9        2753       27171  10.1321
# 10       2728       24117  11.3115
# 11       4215       22395  18.8212
# 12       6059       31960  18.9581
# 13       2177       14540  14.9725
# 14       1230       23151  5.3129
# 15       1102       27353  4.0288
# 16       5018       36492  13.7510
# 17       2198       18391  11.9515
# 18       7532       24005  31.3768
# 19       2106       12382  17.0086
# 20       10010      28638  34.9536

# %%
# Intersect peaks in each cluster with Fibroblast D2 OSKM ChIP from GSE36570 (Soufi et al 2012)

REF=$RES/GSE36570/All_48hrs_MTFBRs.hg38.bed.gz
zcat $REF > tmp.bed

intersection_stats tmp.bed $NUM_BEDS $BEDS

rm tmp.bed
# Out:
# TOTAL PEAKS : 188521
#
# Cluster  Intersect  Total  Percent
# 1        6468       17800  36.3371
# 2        10145      26351  38.4995
# 3        7984       23204  34.4079
# 4        13028      38885  33.5039
# 5        14838      32857  45.1593
# 6        14257      44660  31.9234
# 7        10274      40611  25.2986
# 8        8653       46774  18.4996
# 9        2915       27910  10.4443
# 10       11619      17408  66.7452
# 11       6045       35921  16.8286
# 12       1892       31220  6.0602
# 13       358        13697  2.6137
# 14       4788       39886  12.0042
# 15       2147       20293  10.5800

# %%
# Intersect peaks in each cluster with Fibroblast D2 OSKM ChIP from GSE36570 (Soufi et al 2012)
# separately for O, S, K, M

printf "OCT4\n"
REF=$RES/GSE36570/All_48hrs_MTFBRs.hg38.bed.gz
zcat $REF | grep OCT > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed

printf "\nSOX2\n"
REF=$RES/GSE36570/All_48hrs_MTFBRs.hg38.bed.gz
zcat $REF | grep SOX > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed

printf "\nKLF4\n"
REF=$RES/GSE36570/All_48hrs_MTFBRs.hg38.bed.gz
zcat $REF | grep KLF > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed

printf "\nMYC\n"
REF=$RES/GSE36570/All_48hrs_MTFBRs.hg38.bed.gz
zcat $REF | grep MYC > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed
# Out:
# OCT4
# TOTAL PEAKS : 58148
#
# Cluster  Intersect  Total  Percent
# 1        3117       17800  17.5112
# 2        4937       26351  18.7355
# 3        3113       23204  13.4158
# 4        6076       38885  15.6256
# 5        3805       32857  11.5805
# 6        4314       44660  9.6597
# 7        3744       40611  9.2192
# 8        3377       46774  7.2198
# 9        1024       27910  3.6689
# 10       1757       17408  10.0931
# 11       1918       35921  5.3395
# 12       775        31220  2.4824
# 13       137        13697  1.0002
# 14       1908       39886  4.7836
# 15       947        20293  4.6666
#
# SOX2
# TOTAL PEAKS : 64527
#
# Cluster  Intersect  Total  Percent
# 1        1658       17800  9.3146
# 2        3972       26351  15.0734
# 3        5080       23204  21.8928
# 4        6015       38885  15.4687
# 5        1314       32857  3.9991
# 6        2276       44660  5.0963
# 7        2839       40611  6.9907
# 8        3053       46774  6.5271
# 9        1481       27910  5.3063
# 10       171        17408  0.9823
# 11       840        35921  2.3385
# 12       456        31220  1.4606
# 13       81         13697  0.5914
# 14       1170       39886  2.9334
# 15       411        20293  2.0253
#
# KLF4
# TOTAL PEAKS : 61034
#
# Cluster  Intersect  Total  Percent
# 1        4191       17800  23.5449
# 2        5366       26351  20.3636
# 3        2483       23204  10.7007
# 4        5900       38885  15.1729
# 5        6866       32857  20.8966
# 6        5808       44660  13.0049
# 7        3454       40611  8.5051
# 8        2729       46774  5.8344
# 9        636        27910  2.2788
# 10       6474       17408  37.1898
# 11       2933       35921  8.1651
# 12       875        31220  2.8027
# 13       164        13697  1.1973
# 14       2182       39886  5.4706
# 15       1151       20293  5.6719
#
# MYC
# TOTAL PEAKS : 43946
#
# Cluster  Intersect  Total  Percent
# 1        1717       17800  9.6461
# 2        2349       26351  8.9143
# 3        1013       23204  4.3656
# 4        2164       38885  5.5651
# 5        9863       32857  30.0180
# 6        8124       44660  18.1908
# 7        4871       40611  11.9943
# 8        2979       46774  6.3689
# 9        739        27910  2.6478
# 10       8520       17408  48.9430
# 11       2301       35921  6.4057
# 12       381        31220  1.2204
# 13       63         13697  0.4600
# 14       1124       39886  2.8180
# 15       428        20293  2.1091

# %%
# Intersect peaks in each cluster with Heterokaryon peaks at MRC5/3hr/16hr
printf "MRC5 \n"
REF=/oak/stanford/groups/akundaje/projects/heterokaryon/ATAC-Seq/Batch1/outputs/MRC5_hg38/cromwell-executions/atac/15e37be8-c0e9-4b85-ba0e-8b5c54103fcc/call-reproducibility_overlap/execution/optimal_peak.narrowPeak.gz
zcat $REF > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed

printf "\nCC \n"
REF=/oak/stanford/groups/akundaje/projects/heterokaryon/ATAC-Seq/Batch1/outputs/CC_hg38/cromwell-executions/atac/8a3ac2dd-002d-41c5-88d6-a8c0787309dd/call-reproducibility_overlap/execution/optimal_peak.narrowPeak.gz
zcat $REF > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed

printf "\n3hr \n"
REF=/oak/stanford/groups/akundaje/projects/heterokaryon/ATAC-Seq/Batch1/outputs/3hr_hg38/cromwell-executions/atac/47748a96-e66e-4f7a-b76f-6d2505e8e879/call-reproducibility_overlap/execution/optimal_peak.narrowPeak.gz
zcat $REF > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed

printf "\n16hr \n"
REF=/oak/stanford/groups/akundaje/projects/heterokaryon/ATAC-Seq/Batch1/outputs/16hr_hg38/cromwell-executions/atac/171d7ae4-52db-4f56-8d6e-2270f3a6f827/call-reproducibility_overlap/execution/optimal_peak.narrowPeak.gz
zcat $REF > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed

printf "\n48hr \n"
REF=/oak/stanford/groups/akundaje/projects/heterokaryon/ATAC-Seq/Batch1/outputs/48hr_hg38/cromwell-executions/atac/38d68228-cc1c-44fb-b771-6d33128a7f91/call-reproducibility_overlap/execution/optimal_peak.narrowPeak.gz
zcat $REF > tmp.bed
intersection_stats tmp.bed $NUM_BEDS $BEDS
rm tmp.bed
# Out:
# MRC5
# TOTAL PEAKS : 250320
#
# Cluster  Intersect  Total  Percent
# 1        2368       17800  13.3034
# 2        2875       26351  10.9104
# 3        1341       23204  5.7792
# 4        3447       38885  8.8646
# 5        29114      32857  88.6082
# 6        35426      44660  79.3238
# 7        33169      40611  81.6749
# 8        32411      46774  69.2928
# 9        17835      27910  63.9018
# 10       17210      17408  98.8626
# 11       14025      35921  39.0440
# 12       1749       31220  5.6022
# 13       162        13697  1.1827
# 14       8977       39886  22.5066
# 15       1081       20293  5.3270
#
# CC
# TOTAL PEAKS : 169066
#
# Cluster  Intersect  Total  Percent
# 1        1353       17800  7.6011
# 2        1844       26351  6.9978
# 3        798        23204  3.4391
# 4        2170       38885  5.5806
# 5        25768      32857  78.4247
# 6        27804      44660  62.2571
# 7        27734      40611  68.2918
# 8        25014      46774  53.4784
# 9        12702      27910  45.5106
# 10       16931      17408  97.2599
# 11       7627       35921  21.2327
# 12       716        31220  2.2934
# 13       65         13697  0.4746
# 14       4746       39886  11.8989
# 15       495        20293  2.4393
#
# 3hr
# TOTAL PEAKS : 194478
#
# Cluster  Intersect  Total  Percent
# 1        3247       17800  18.2416
# 2        3306       26351  12.5460
# 3        955        23204  4.1157
# 4        3108       38885  7.9928
# 5        25581      32857  77.8556
# 6        30152      44660  67.5146
# 7        29401      40611  72.3966
# 8        26822      46774  57.3438
# 9        12560      27910  45.0018
# 10       16204      17408  93.0836
# 11       9546       35921  26.5750
# 12       983        31220  3.1486
# 13       86         13697  0.6279
# 14       6368       39886  15.9655
# 15       883        20293  4.3513
#
# 16hr
# TOTAL PEAKS : 188309
#
# Cluster  Intersect  Total  Percent
# 1        4525       17800  25.4213
# 2        2848       26351  10.8079
# 3        742        23204  3.1977
# 4        2367       38885  6.0872
# 5        28271      32857  86.0425
# 6        31424      44660  70.3627
# 7        26976      40611  66.4254
# 8        23117      46774  49.4228
# 9        9642       27910  34.5468
# 10       17046      17408  97.9205
# 11       12697      35921  35.3470
# 12       2418       31220  7.7450
# 13       269        13697  1.9639
# 14       8136       39886  20.3981
# 15       2419       20293  11.9204
#
# 48hr
# TOTAL PEAKS : 207973
#
# Cluster  Intersect  Total  Percent
# 1        4135       17800  23.2303
# 2        2457       26351  9.3241
# 3        721        23204  3.1072
# 4        2192       38885  5.6371
# 5        27307      32857  83.1086
# 6        32234      44660  72.1764
# 7        27519      40611  67.7624
# 8        22943      46774  49.0508
# 9        8764       27910  31.4009
# 10       16714      17408  96.0133
# 11       13840      35921  38.5290
# 12       2588       31220  8.2896
# 13       275        13697  2.0077
# 14       9004       39886  22.5743
# 15       2714       20293  13.3741

# %%
# Intersect peaks in each cluster with day-wise data to compare with hets 

for x in D0 D2 D4 D6 D10 D12 D14
    do 
        printf "\n$x \n"
        REF=/oak/stanford/groups/akundaje/surag/projects/scATAC-reprog/bulk/croo/$x/peak/overlap_reproducibility/overlap.optimal_peak.narrowPeak.gz
        zcat $REF > tmp.bed
        intersection_stats tmp.bed $NUM_BEDS $BEDS
        rm tmp.bed
    done
# Out:
# D0
# TOTAL PEAKS : 286556
#
# Cluster  Intersect  Total  Percent
# 1        738        17800  4.1461
# 2        943        26351  3.5786
# 3        706        23204  3.0426
# 4        1211       38885  3.1143
# 5        30777      32857  93.6695
# 6        38700      44660  86.6547
# 7        34551      40611  85.0779
# 8        29521      46774  63.1141
# 9        13358      27910  47.8610
# 10       17345      17408  99.6381
# 11       12286      35921  34.2028
# 12       652        31220  2.0884
# 13       101        13697  0.7374
# 14       4532       39886  11.3624
# 15       378        20293  1.8627
#
# D2
# TOTAL PEAKS : 281304
#
# Cluster  Intersect  Total  Percent
# 1        9577       17800  53.8034
# 2        12918      26351  49.0228
# 3        3691       23204  15.9067
# 4        10474      38885  26.9358
# 5        31747      32857  96.6217
# 6        35411      44660  79.2902
# 7        21451      40611  52.8207
# 8        11885      46774  25.4094
# 9        2406       27910  8.6206
# 10       17393      17408  99.9138
# 11       9841       35921  27.3962
# 12       749        31220  2.3991
# 13       82         13697  0.5987
# 14       4305       39886  10.7933
# 15       1152       20293  5.6768
#
# D4
# TOTAL PEAKS : 282608
#
# Cluster  Intersect  Total  Percent
# 1        13728      17800  77.1236
# 2        15700      26351  59.5803
# 3        1550       23204  6.6799
# 4        6508       38885  16.7365
# 5        32257      32857  98.1739
# 6        38832      44660  86.9503
# 7        27374      40611  67.4054
# 8        14119      46774  30.1856
# 9        3204       27910  11.4798
# 10       17399      17408  99.9483
# 11       13790      35921  38.3898
# 12       1369       31220  4.3850
# 13       122        13697  0.8907
# 14       5904       39886  14.8022
# 15       2728       20293  13.4431
#
# D6
# TOTAL PEAKS : 282442
#
# Cluster  Intersect  Total  Percent
# 1        15918      17800  89.4270
# 2        14214      26351  53.9410
# 3        866        23204  3.7321
# 4        4061       38885  10.4436
# 5        32223      32857  98.0704
# 6        38692      44660  86.6368
# 7        22470      40611  55.3298
# 8        11456      46774  24.4922
# 9        2351       27910  8.4235
# 10       17396      17408  99.9311
# 11       19251      35921  53.5926
# 12       2936       31220  9.4042
# 13       270        13697  1.9712
# 14       9352       39886  23.4468
# 15       7475       20293  36.8354
#
# D10
# TOTAL PEAKS : 280693
#
# Cluster  Intersect  Total  Percent
# 1        12655      17800  71.0955
# 2        3403       26351  12.9141
# 3        509        23204  2.1936
# 4        1348       38885  3.4666
# 5        32162      32857  97.8848
# 6        38050      44660  85.1993
# 7        23318      40611  57.4179
# 8        12085      46774  25.8370
# 9        2600       27910  9.3157
# 10       17401      17408  99.9598
# 11       18547      35921  51.6327
# 12       2917       31220  9.3434
# 13       484        13697  3.5336
# 14       7325       39886  18.3648
# 15       7675       20293  37.8209
#
# D12
# TOTAL PEAKS : 273919
#
# Cluster  Intersect  Total  Percent
# 1        12240      17800  68.7640
# 2        2095       26351  7.9504
# 3        423        23204  1.8230
# 4        930        38885  2.3917
# 5        31317      32857  95.3130
# 6        33752      44660  75.5755
# 7        11352      40611  27.9530
# 8        5341       46774  11.4187
# 9        930        27910  3.3321
# 10       17383      17408  99.8564
# 11       22725      35921  63.2638
# 12       8098       31220  25.9385
# 13       2490       13697  18.1792
# 14       9340       39886  23.4167
# 15       13557      20293  66.8063
#
# D14
# TOTAL PEAKS : 272479
#
# Cluster  Intersect  Total  Percent
# 1        11093      17800  62.3202
# 2        1640       26351  6.2237
# 3        384        23204  1.6549
# 4        829        38885  2.1319
# 5        30109      32857  91.6365
# 6        30673      44660  68.6811
# 7        8700       40611  21.4228
# 8        3950       46774  8.4449
# 9        680        27910  2.4364
# 10       17371      17408  99.7875
# 11       23424      35921  65.2098
# 12       11661      31220  37.3511
# 13       4724       13697  34.4893
# 14       10898      39886  27.3229
# 15       13902      20293  68.5064
